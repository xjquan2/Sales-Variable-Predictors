# %%
# %matplotlib inline

import pandas as pd  
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor

from sklearn.linear_model import Lasso

import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %matplotlib inline
from dmba import regressionSummary, adjusted_r2_score, plotDecisionTree

# %%
data_df = pd.read_csv("historical_data.csv")

# %%
ax = data_df.groupby('Package_Type').sales.max().plot(kind='bar', 
                                                                      figsize=[10, 6], 
                                                                      color='coral')

ax.set_ylabel('sales')

plt.tight_layout()
plt.show()

# %%
data_df.groupby(["Package_Type"]).sum().plot(kind = "pie", y = "sales", figsize = (8,8), legend = None, autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='sales'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=[30,30])
data_df.Type.hist(ax=axes)
axes.set_xlabel('type')
axes.set_ylabel('count')


plt.show()
